# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img = cv.imread("bj-coin.png")

dst = cv.fastNlMeansDenoisingColored(img,None,10,10,7,21)

plt.subplot(121),plt.imshow(img)
plt.subplot(122),plt.imshow(dst)
plt.show()

# %%
filename = 'billiejean.mp4'
video = cv.VideoCapture(filename)
fps = video.get(cv.CAP_PROP_FPS)
width  = int(video.get(cv.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv.CAP_PROP_FRAME_HEIGHT))
fourcc = cv.VideoWriter_fourcc('P','I','M','1')
out_filename = "{}-DENOISED.mkv".format(filename)
print("Frames per second: {}".format(fps))
# Out:
# Frames per second: 29.97002997002997

# %%
out = cv2.VideoWriter(out_filename, fourcc, fps, (width,height))

while(video.isOpened()):
    ret, frame = cap.read()
    dst = cv.fastNlMeansDenoisingColored(frame,None,10,10,7,21)
    out.write(dst)
out.release()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-94-104fdd0c72a1> in <module>
#       3 while(video.isOpened()):
#       4     ret, frame = cap.read()
# ----> 5     dst = cv.fastNlMeansDenoisingColored(frame,None,10,10,7,21)
#       6     out.write(dst)
#       7 out.release()
#
# error: OpenCV(4.3.0) /io/opencv/modules/photo/src/denoising.cpp:178: error: (-5:Bad argument) Type of input image should be CV_8UC3 or CV_8UC4! in function 'fastNlMeansDenoisingColored'

# %%
plt.imshow(dst,'gray')
plt.show()
